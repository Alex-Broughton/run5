# %% [markdown]
# # CTI Correction
#
# This shows the difference between the parallel (0,1) turnoff and the serial (1,0) turnoff.
# The code to generate the eotest file can be found here: https://github.com/lsst-camera-dh/eotest/blob/594625ba31db62a75ed802da8d90ba2dc19a71e8/python/lsst/eotest/sensor/BFTask.py

# %%
! eups list -s | grep lsst_distrib
# Out:
# lsst_distrib          g4213664e8e+da93b84f60 	current w_2023_37 setup

# %%
slacAmps = {'C10':'AMP01','C11':'AMP02','C12':'AMP03','C13':'AMP04',\
           'C14':'AMP05','C15':'AMP06','C16':'AMP07','C17':'AMP08',\
           'C07':'AMP09','C06':'AMP10','C05':'AMP11','C04':'AMP12',\
           'C03':'AMP13','C02':'AMP14','C01':'AMP15','C00':'AMP16'}### Single Amplifier:

# %%
slacAmps = {'C10':'AMP01','C11':'AMP02','C12':'AMP03','C13':'AMP04',\
           'C14':'AMP05','C15':'AMP06','C16':'AMP07','C17':'AMP08',\
           'C07':'AMP09','C06':'AMP10','C05':'AMP11','C04':'AMP12',\
           'C03':'AMP13','C02':'AMP14','C01':'AMP15','C00':'AMP16'}
slacAmps2 = {y: x for x, y in slacAmps.items()}

# %%
from lsst.daf.butler import Butler
from lsst.obs.lsst import LsstCam

# %% [markdown]
# ## R03-S12 (ITL)

# %%
butler = Butler("/repo/main")
cti = butler.get('cpCtiCalib', detector=23, instrument='LSSTCam', collections='u/cslage/sdf/BOT/cti_test_20230106')

# %%
# Get the gains on each amplifier in order to do background illumination subtraction
#Get the PTC collections
from lsst.daf.butler import Butler
from lsst.obs.lsst import LsstCam
sensor="R03_S12"
butler = Butler("/repo/main")
cti = butler.get('cpCtiCalib', detector=23, instrument='LSSTCam', collections='u/cslage/sdf/BOT/cti_test_20230106')

camera = LsstCam().getCamera()
detector = camera.get("R03_S12")
help(cti)
# Out:
# Help on DeferredChargeCalib in module lsst.ip.isr.deferredCharge object:
#
# class DeferredChargeCalib(lsst.ip.isr.calibType.IsrCalib)
#  |  DeferredChargeCalib(**kwargs)
#  |
#  |  Calibration containing deferred charge/CTI parameters.
#  |
#  |  Parameters
#  |  ----------
#  |  **kwargs :
#  |      Additional parameters to pass to parent constructor.
#  |
#  |  Notes
#  |  -----
#  |  The charge transfer inefficiency attributes stored are:
#  |
#  |  driftScale : `dict` [`str`, `float`]
#  |      A dictionary, keyed by amplifier name, of the local electronic
#  |      offset drift scale parameter, A_L in Snyder+2021.
#  |  decayTime : `dict` [`str`, `float`]
#  |      A dictionary, keyed by amplifier name, of the local electronic
#  |      offset decay time, \tau_L in Snyder+2021.
#  |  globalCti : `dict` [`str`, `float`]
#  |      A dictionary, keyed by amplifier name, of the mean global CTI
#  |      paramter, b in Snyder+2021.
# ...

# %%
cti.globalCti['C00']
# Out:
# 5.636578918339998e-07

# %%
# Get the gains on each amplifier in order to do background illumination subtraction
#Get the PTC collections
from lsst.daf.butler import Butler
from lsst.obs.lsst import LsstCam
sensor="R03_S12"
butler = Butler("/repo/main")
cti = butler.get('cpCtiCalib', detector=9, instrument='LSSTCam', collections='u/abrought/BF/2023.04.14/cti.2023.04.14')

camera = LsstCam().getCamera()
detector = camera.get("R03_S12")

# %%
cti.globalCti['C00']
# Out:
# 3.3565887420042596e-07
