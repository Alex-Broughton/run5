plt.plot(np.linspace(0,50,50), m*np.linspace(0,50,50) + b)
print("#1200: ",m,"e-/s ",b, "e-")
plt.scatter(exptimes, real_spot_sky_230, label = "#0230 (edge)")
m,b = np.polyfit(exptimes, real_spot_sky_230, 1)
plt.plot(np.linspace(0,50,50), m*np.linspace(0,50,50) + b)
print("#0230: ",m,"e-/s ", b, "e-")
plt.xlabel("Exptime [s]")
plt.ylabel("Signal [e-]")
l = plt.legend()
# Out:
# #1200:  30.759962583908123 e-/s  -5.261308907047567 e-
# #0230:  1.9901072999733975 e-/s  -1.1267164343221527 e-

# %% [markdown]
# ## 1.25s Spot (#1200)

# %%
# model atmospheric turbulence as a VonKarman, with some small shear
#gprof = galsim.VonKarman(lam=1000.,r0=0.2,L0=10.0).shear(g1=0.06, g2=-0.05)

# add 4.5 microns sigma of Gaussian to model diffusion
# convert 4.5 microns to arcsec with factor 0.2"/10micron 
pixscale = 0.2/10.e-6
dprof = galsim.Gaussian(sigma=2.30677178e-6*pixscale)

# Airy function to simulate diffraction through mask
lam_over_diam = 0.00000475  # radians
lam_over_diam *= 206265  # Convert to arcsec
airy = galsim.Airy(lam_over_diam)


# add optical term, making up reasonable Zernike terms
#oprof = galsim.OpticalPSF(lam=700.0,diam=8.4,
#                          defocus = 0.,coma1 = 0, coma2 = 0.0, astig1 = 1.2, astig2 = 1.2,
#                          obscuration = 0.0)

# convolve these terms
prof = galsim.Convolve([dprof,airy]).shear(e1=-0.05, e2=0.06).withFlux(305180*.91893*1.08*.93*1.08*1.006*.95)
#prof = galsim.Add([prof,fprof])

# add BF effect
sensor = galsim.SiliconSensor(strength = 1.4, diffusion_factor=1., nrecalc=1000)
#sensor = galsim.SiliconSensor(strength = 1., diffusion_factor=1., nrecalc=1000)

# draw image
blank_image = galsim.Image(65*3,65*3,scale=0.2,xmin=0,ymin=0,dtype=np.float64)  
star_image1 = prof.drawImage(image=blank_image, offset=(-65.,0), scale=0.2, sensor=sensor, method="phot", save_photons=True)
star_image2 = prof.drawImage(image=star_image1, offset=(-65.,65.), scale=0.2, sensor=sensor, method="phot", save_photons=True,add_to_image=True)
star_image3 = prof.drawImage(image=star_image2, offset=(0,65.), scale=0.2, sensor=sensor, method="phot", save_photons=True,add_to_image=True)
star_image4 = prof.drawImage(image=star_image3, offset=(65.,65.), scale=0.2, sensor=sensor, method="phot", save_photons=True,add_to_image=True)
star_image5 = prof.drawImage(image=star_image4, offset=(65.,0), scale=0.2, sensor=sensor, method="phot", save_photons=True,add_to_image=True)
star_image6 = prof.drawImage(image=star_image5, offset=(65.,-65), scale=0.2, sensor=sensor, method="phot", save_photons=True,add_to_image=True)
star_image7 = prof.drawImage(image=star_image6, offset=(0,-65), scale=0.2, sensor=sensor, method="phot", save_photons=True,add_to_image=True)
star_image8 = prof.drawImage(image=star_image7, offset=(-65.,-65.), scale=0.2, sensor=sensor, method="phot", save_photons=True,add_to_image=True)
star_image = prof.drawImage(image=star_image8, scale=0.2, sensor=sensor, method="phot", save_photons=True,add_to_image=True)
star_image += 118*1.25

stamps_wBF = []
for n in range(20):
    # random seed
    rng = galsim.BaseDeviate(n)
    temp = galsim.Image(star_image, dtype=star_image.dtype, copy=True)
    
    # generate noise and add to image
    #noise = galsim.GaussianNoise(rng,sigma=4.7)
    #noise = galsim.CCDNoise(rng, gain=1.5, read_noise=4.7, sky_level=0.0)
    #temp.addNoise(noise)
    stamp = temp.subImage(galsim.BoundsI(temp.center.x - 33, temp.center.x + 33, temp.center.y - 33, temp.center.y + 33))
    stamps_wBF.append(galsim.Image(stamp.array))

# calculate HSM moments (these are in pixel coordinates)

mom = stamps_wBF[0].FindAdaptiveMom(weight=None, strict=False)
print("Sigma = ",mom.moments_sigma)
print("Flux = ",mom.moments_amp)
print("Shear = ",mom.observed_shape)
print("Centroid = ",mom.moments_centroid)
print()

# plot it
f,ax = plt.subplots(1,1, figsize=(8,6))
from matplotlib.colors import LogNorm
stamp = star_image.array
print("Noise sigma = ", np.std(stamp[0:15,0:15]))
print("RMS Noise = ", np.sqrt(np.mean(stamp[0:15,0:15].flatten()**2)) )
stamp[stamp <= 1] = np.mean(stamp[0:10,0:10])
im = ax.imshow(stamp,origin='lower',interpolation='None', cmap="gray", norm=LogNorm())
f.colorbar(im,ax=ax)
#2.092710494995117
# Out:
# Sigma =  2.1521506309509277
# Flux =  269513.125
# Shear =  galsim.Shear(g1=-0.02128490496286698,g2=0.028642399308288196)
# Centroid =  galsim.PositionD(33.9975274731151,34.00700700007709)
#
# Noise sigma =  1.4842315216557498
# RMS Noise =  148.956283668882

# %%
# model atmospheric turbulence as a VonKarman, with some small shear
#gprof = galsim.VonKarman(lam=1000.,r0=0.2,L0=10.0).shear(g1=0.06, g2=-0.05)

# add 4.5 microns sigma of Gaussian to model diffusion
# convert 4.5 microns to arcsec with factor 0.2"/10micron 
pixscale = 0.2/10.e-6
dprof = galsim.Gaussian(sigma=2.30677178e-6*pixscale)

# Airy function to simulate diffraction through mask
lam_over_diam = 0.00000475  # radians
lam_over_diam *= 206265  # Convert to arcsec
airy = galsim.Airy(lam_over_diam)


# add optical term, making up reasonable Zernike terms
#oprof = galsim.OpticalPSF(lam=700.0,diam=8.4,
#                          defocus = 0.,coma1 = 0, coma2 = 0.0, astig1 = 1.2, astig2 = 1.2,
#                          obscuration = 0.0)

# convolve these terms
prof = galsim.Convolve([dprof,airy]).shear(e1=-0.05, e2=0.06).withFlux(305180*.91893*1.08*.93*1.08*1.006*.95)
#prof = galsim.Add([prof,fprof])

# add BF effect
#sensor = galsim.SiliconSensor(strength = 1.4, diffusion_factor=1.75, nrecalc=1000)
#sensor = galsim.SiliconSensor(strength = 1., diffusion_factor=1., nrecalc=1000)

# draw image
blank_image = galsim.Image(65*3,65*3,scale=0.2,xmin=0,ymin=0,dtype=np.float64)  
star_image1 = prof.drawImage(image=blank_image, offset=(-65.,0), scale=0.2, method="phot", save_photons=True)
star_image2 = prof.drawImage(image=star_image1, offset=(-65.,65.), scale=0.2, method="phot", save_photons=True,add_to_image=True)
star_image3 = prof.drawImage(image=star_image2, offset=(0,65.), scale=0.2, method="phot", save_photons=True,add_to_image=True)
star_image4 = prof.drawImage(image=star_image3, offset=(65.,65.), scale=0.2, method="phot", save_photons=True,add_to_image=True)
star_image5 = prof.drawImage(image=star_image4, offset=(65.,0), scale=0.2, method="phot", save_photons=True,add_to_image=True)
star_image6 = prof.drawImage(image=star_image5, offset=(65.,-65), scale=0.2, method="phot", save_photons=True,add_to_image=True)
star_image7 = prof.drawImage(image=star_image6, offset=(0,-65), scale=0.2, method="phot", save_photons=True,add_to_image=True)
star_image8 = prof.drawImage(image=star_image7, offset=(-65.,-65.), scale=0.2, method="phot", save_photons=True,add_to_image=True)
star_image = prof.drawImage(image=star_image8, scale=0.2, method="phot", save_photons=True,add_to_image=True)
star_image += 118*1.25

stamps = []
for n in range(20):
    # random seed
    rng = galsim.BaseDeviate(n)
    temp = galsim.Image(star_image, dtype=star_image.dtype, copy=True)
    
    # generate noise and add to image
    #noise = galsim.GaussianNoise(rng,sigma=4.7)
    #noise = galsim.CCDNoise(rng, gain=1.5, read_noise=4.7, sky_level=0.0)
    #temp.addNoise(noise)
    stamp = temp.subImage(galsim.BoundsI(temp.center.x - 33, temp.center.x + 33, temp.center.y - 33, temp.center.y + 33))
    stamps.append(galsim.Image(stamp.array))

# calculate HSM moments (these are in pixel coordinates)

mom = stamps[0].FindAdaptiveMom(weight=None, strict=False)
print("Sigma = ",mom.moments_sigma)
print("Flux = ",mom.moments_amp)
print("Shear = ",mom.observed_shape)
print("Centroid = ",mom.moments_centroid)
print()

# plot it
f,ax = plt.subplots(1,1, figsize=(8,6))
from matplotlib.colors import LogNorm
stamp = star_image.array
print("Noise sigma = ", np.std(stamp[0:15,0:15]))
print("RMS Noise = ", np.sqrt(np.mean(stamp[0:15,0:15].flatten()**2)) )
stamp[stamp <= 1] = np.mean(stamp[0:10,0:10])
im = ax.imshow(stamp,origin='lower',interpolation='None', cmap="gray", norm=LogNorm())
f.colorbar(im,ax=ax)
# Out:
# Sigma =  2.1058523654937744
# Flux =  269114.4375
# Shear =  galsim.Shear(g1=-0.025705288853395087,g2=0.031494524335312406)
# Centroid =  galsim.PositionD(33.998745893975546,34.012511229807046)
#
# Noise sigma =  1.4863062177221442
# RMS Noise =  148.80520077530144

# %%
plt.figure(figsize=(10,8), facecolor="white")
for px in range(50): plt.axvline(px, linestyle="--", lw=0.5, alpha=0.5, color="k")

def BinnedSpot(stamps):
    stamp = stamps[0]
    x = stamp.center.x
    y = stamp.center.y

    xs, ys = np.meshgrid(np.arange(stamp.array.shape[0]), np.arange(stamp.array.shape[1]))
    r = np.sqrt((xs - x)**2 + (ys - y)**2)
    radii = np.ravel([np.ravel(r) for n in range(len(stamps))])
    signals = np.ravel([np.ravel(i.array) for i in stamps])

    bins = np.linspace(0, 50, 200)

    y = []
    for j in range(len(bins)-1):

        cond = (radii>=bins[j]) & (radii<bins[j+1])
        selected_intensities = signals[cond]
        #print(selected_intensities.size)

        if selected_intensities.size==0:
            if j==0:
                y.append(np.nan)
            else:
                y.append(y[j-1])
        else:
            if selected_intensities.mean() == 0:
                y.append(y[j-1])
            else:
                y.append(selected_intensities.mean())

    return bins[0:-1], np.asarray(y)

x, y     = BinnedSpot(stamps)
x, y_wBF = BinnedSpot(stamps_wBF)

#from lmfit.models import GaussianModel
#model = GaussianModel()
#params = model.make_params(amplitude=np.sum(y), sigma=1, center=65.)
#params['center'].vary = False  # fix the centroid at 0
#result = model.fit(y, params, x=bins[0:-1]+65.)
#bkg = result.eval(x=bins[0:-1])

            
plt.plot(x, y, label='Simulated')
plt.plot(x, y_wBF, label='Simulated (incl. BF)')
plt.plot(x,real_spot_y_1200_1_25s, label='Real (radial avg. of spot #1200)')
print(np.max(y),np.sum(y),y[-1])
print(np.max(y_wBF),np.sum(y_wBF),y_wBF[-1])
print(np.max(real_spot_y_1200_1_25s),np.sum(real_spot_y_1200_1_25s), real_spot_y_1200_1_25s[-1])

plt.title('Spot Profile (1.25s)', fontsize=15)
plt.xlim(0,45)
plt.xticks([0,5,10,15,20,25,30,35,40,45], fontsize=15)
plt.yticks(fontsize=15)
plt.yscale('log')
#plt.xlim(0,10)
#plt.ylim(.1,1e5)
plt.legend(fontsize=14)
plt.xlabel('$r - r_{centroid}$ [px]', fontsize=15)
plt.ylabel('$F$ [e-]', fontsize=15)
# Out:
# 7726.5 120421.26651321672 150.5
# 7658.5 119353.96704119294 151.5
# 7845.788464355469 93466.83686211395 5.472823990881443
# Text(0, 0.5, '$F$ [e-]')

# %% [markdown]
# #### 20.0s Spot (#1200)

# %%
# model atmospheric turbulence as a VonKarman, with some small shear
#gprof = galsim.VonKarman(lam=1000.,r0=0.2,L0=10.0).shear(g1=0.06, g2=-0.05)

# add 4.5 microns sigma of Gaussian to model diffusion
# convert 4.5 microns to arcsec with factor 0.2"/10micron 
pixscale = 0.2/10.e-6
dprof = galsim.Gaussian(sigma=2.00677178e-6*pixscale)

# Airy function to simulate diffraction through mask
lam_over_diam = 0.00000475  # radians
lam_over_diam *= 206265  # Convert to arcsec
airy = galsim.Airy(lam_over_diam)


# add optical term, making up reasonable Zernike terms
#oprof = galsim.OpticalPSF(lam=700.0,diam=8.4,
#                          defocus = 0.,coma1 = 0, coma2 = 0.0, astig1 = 1.2, astig2 = 1.2,
#                          obscuration = 0.0)

# convolve these terms
prof = galsim.Convolve([dprof,airy]).shear(e1=-0.05, e2=0.06).withFlux(305180*.91893*1.08*1.08*.93*1.006*.95*(20./1.25))
#prof = galsim.Add([prof,fprof])

# add BF effect
#sensor = galsim.SiliconSensor(strength = 1.4, diffusion_factor=1.75, nrecalc=1000)
sensor = galsim.SiliconSensor(strength = 1., diffusion_factor=1., nrecalc=10000)

# draw image
blank_image = galsim.Image(65*3,65*3,scale=0.2,xmin=0,ymin=0,dtype=np.float64)  
star_image1 = prof.drawImage(image=blank_image, offset=(-65.,0), scale=0.2, sensor=sensor, method="phot", save_photons=True)
star_image2 = prof.drawImage(image=star_image1, offset=(-65.,65.), scale=0.2, sensor=sensor, method="phot", save_photons=True,add_to_image=True)
star_image3 = prof.drawImage(image=star_image2, offset=(0,65.), scale=0.2, sensor=sensor, method="phot", save_photons=True,add_to_image=True)
star_image4 = prof.drawImage(image=star_image3, offset=(65.,65.), scale=0.2, sensor=sensor, method="phot", save_photons=True,add_to_image=True)
star_image5 = prof.drawImage(image=star_image4, offset=(65.,0), scale=0.2, sensor=sensor, method="phot", save_photons=True,add_to_image=True)
star_image6 = prof.drawImage(image=star_image5, offset=(65.,-65), scale=0.2, sensor=sensor, method="phot", save_photons=True,add_to_image=True)
star_image7 = prof.drawImage(image=star_image6, offset=(0,-65), scale=0.2, sensor=sensor, method="phot", save_photons=True,add_to_image=True)
star_image8 = prof.drawImage(image=star_image7, offset=(-65.,-65.), scale=0.2, sensor=sensor, method="phot", save_photons=True,add_to_image=True)
star_image = prof.drawImage(image=star_image8, scale=0.2, sensor=sensor, method="phot", save_photons=True,add_to_image=True)
star_image += 118.0*20

stamps_wBF = []
for n in range(20):
    # random seed
    rng = galsim.BaseDeviate(n)
    temp = galsim.Image(star_image, dtype=star_image.dtype, copy=True)
    
    # generate noise and add to image
    noise = galsim.CCDNoise(rng, gain=1.5, read_noise=4.7, sky_level=0)
    temp.addNoise(noise)
    stamp = temp.subImage(galsim.BoundsI(temp.center.x - 33, temp.center.x + 33, temp.center.y - 33, temp.center.y + 33))
    stamps_wBF.append(galsim.Image(stamp.array))

# calculate HSM moments (these are in pixel coordinates)

mom = stamps_wBF[0].FindAdaptiveMom(weight=None, strict=False)
print("Sigma = ",mom.moments_sigma)
print("Flux = ",mom.moments_amp)
print("Shear = ",mom.observed_shape)
print("Centroid = ",mom.moments_centroid)
print()

# plot it
f,ax = plt.subplots(1,1, figsize=(8,6))
from matplotlib.colors import LogNorm
stamp = star_image.array
print("Noise sigma = ", np.std(stamp[0:15,0:15]))
print("RMS Noise = ", np.sqrt(np.mean(stamp[0:15,0:15].flatten()**2)) )
stamp[stamp <= 1] = np.mean(stamp[0:10,0:10])
im = ax.imshow(stamp,origin='lower',interpolation='None', cmap="gray", norm=LogNorm())
f.colorbar(im,ax=ax)
# Out:
# Sigma =  2.1671924591064453
# Flux =  4328356.5
# Shear =  galsim.Shear(g1=-0.022988957631127103,g2=0.02790550438771236)
# Centroid =  galsim.PositionD(34.0011242210567,33.99811355732808)
#
# Noise sigma =  13.874926315008434
# RMS Noise =  2382.2848500266855

# %%
# model atmospheric turbulence as a VonKarman, with some small shear
#gprof = galsim.VonKarman(lam=1000.,r0=0.2,L0=10.0).shear(g1=0.06, g2=-0.05)

# add 4.5 microns sigma of Gaussian to model diffusion
# convert 4.5 microns to arcsec with factor 0.2"/10micron 
pixscale = 0.2/10.e-6
dprof = galsim.Gaussian(sigma=2.00677178e-6*pixscale)

# Airy function to simulate diffraction through mask
lam_over_diam = 0.00000475  # radians
lam_over_diam *= 206265  # Convert to arcsec
airy = galsim.Airy(lam_over_diam)


# add optical term, making up reasonable Zernike terms
#oprof = galsim.OpticalPSF(lam=700.0,diam=8.4,
#                          defocus = 0.,coma1 = 0, coma2 = 0.0, astig1 = 1.2, astig2 = 1.2,
#                          obscuration = 0.0)

# convolve these terms
prof = galsim.Convolve([dprof,airy]).shear(e1=-0.05, e2=0.06).withFlux(305180*.91893*1.08*.93*1.08*1.006*.95*(20./1.25))
#prof = galsim.Add([prof,fprof])

# add BF effect
#sensor = galsim.SiliconSensor(strength = 1.4, diffusion_factor=1.75, nrecalc=10000)
sensor = galsim.SiliconSensor(strength = 1., diffusion_factor=1., nrecalc=1000)

# draw image
blank_image = galsim.Image(65*3,65*3,scale=0.2,xmin=0,ymin=0,dtype=np.float64)  
star_image1 = prof.drawImage(image=blank_image, offset=(-65.,0), scale=0.2, method="phot", save_photons=True)
star_image2 = prof.drawImage(image=star_image1, offset=(-65.,65.), scale=0.2, method="phot", save_photons=True,add_to_image=True)
star_image3 = prof.drawImage(image=star_image2, offset=(0,65.), scale=0.2, method="phot", save_photons=True,add_to_image=True)
star_image4 = prof.drawImage(image=star_image3, offset=(65.,65.), scale=0.2, method="phot", save_photons=True,add_to_image=True)
star_image5 = prof.drawImage(image=star_image4, offset=(65.,0), scale=0.2, method="phot", save_photons=True,add_to_image=True)
star_image6 = prof.drawImage(image=star_image5, offset=(65.,-65), scale=0.2, method="phot", save_photons=True,add_to_image=True)
star_image7 = prof.drawImage(image=star_image6, offset=(0,-65), scale=0.2, method="phot", save_photons=True,add_to_image=True)
star_image8 = prof.drawImage(image=star_image7, offset=(-65.,-65.), scale=0.2, method="phot", save_photons=True,add_to_image=True)
star_image = prof.drawImage(image=star_image8, scale=0.2, method="phot", save_photons=True,add_to_image=True)
star_image += 118*20

stamps = []
for n in range(1):
    # random seed
    rng = galsim.BaseDeviate(n)
    temp = galsim.Image(star_image, dtype=star_image.dtype, copy=True)
    
    # generate noise and add to image
    noise = galsim.CCDNoise(rng, gain=1.5, read_noise=4.7, sky_level=0)
    temp.addNoise(noise)
    stamp = temp.subImage(galsim.BoundsI(temp.center.x - 33, temp.center.x + 33, temp.center.y - 33, temp.center.y + 33))
    stamps.append(galsim.Image(stamp.array))

# calculate HSM moments (these are in pixel coordinates)

mom = stamps[0].FindAdaptiveMom(weight=None, strict=False)
print("Sigma = ",mom.moments_sigma)
print("Flux = ",mom.moments_amp)
print("Shear = ",mom.observed_shape)
print("Centroid = ",mom.moments_centroid)
print()

# plot it
f,ax = plt.subplots(1,1, figsize=(8,6))
from matplotlib.colors import LogNorm
stamp = star_image.array
print("Noise sigma = ", np.std(stamp[0:15,0:15]))
print("RMS Noise = ", np.sqrt(np.mean(stamp[0:15,0:15].flatten()**2)) )
stamp[stamp <= 1] = np.mean(stamp[0:10,0:10])
im = ax.imshow(stamp,origin='lower',interpolation='None', cmap="gray", norm=LogNorm())
f.colorbar(im,ax=ax)
# Out:
# Sigma =  2.1063122749328613
# Flux =  4313337.0
# Shear =  galsim.Shear(g1=-0.023932439775428128,g2=0.02983383019733767)
# Centroid =  galsim.PositionD(33.99662838915669,33.99870314893958)
#
# Noise sigma =  15.53950664167517
# RMS Noise =  2382.237349869049

# %%
plt.figure(figsize=(10,8), facecolor="white")
for px in range(50): plt.axvline(px, linestyle="--", lw=0.5, alpha=0.5, color="k")

def BinnedSpot(stamps):
    stamp = stamps[0]
    x = stamp.center.x
    y = stamp.center.y

    xs, ys = np.meshgrid(np.arange(stamp.array.shape[0]), np.arange(stamp.array.shape[1]))
    r = np.sqrt((xs - x)**2 + (ys - y)**2)
    radii = np.ravel([np.ravel(r) for n in range(len(stamps))])
    signals = np.ravel([np.ravel(i.array) for i in stamps])

    bins = np.linspace(0, 50, 200)

    y = []
    for j in range(len(bins)-1):

        cond = (radii>=bins[j]) & (radii<bins[j+1])
        selected_intensities = signals[cond]
        #print(selected_intensities.size)

        if selected_intensities.size==0:
            if j==0:
                y.append(np.nan)
            else:
                y.append(y[j-1])
        else:
            if selected_intensities.mean() == 0:
                y.append(y[j-1])
            else:
                y.append(selected_intensities.mean())

    return bins[0:-1], np.asarray(y)

x, y     = BinnedSpot(stamps)
x, y_wBF = BinnedSpot(stamps_wBF)

#from lmfit.models import GaussianModel
#model = GaussianModel()
#params = model.make_params(amplitude=np.sum(y), sigma=1, center=65.)
#params['center'].vary = False  # fix the centroid at 0
#result = model.fit(y, params, x=bins[0:-1]+65.)
#bkg = result.eval(x=bins[0:-1])

            
plt.plot(x, y, label='Simulated')
plt.plot(x, y_wBF, label='Simulated (incl. BF)')
plt.plot(x,real_spot_y_1200_20s, label='Real (radial avg. of spot #1200)')
print(np.max(y),np.sum(y),np.mean(y[35:45]))
print(np.max(y_wBF),np.sum(y_wBF),np.mean(y_wBF[35:45]))
print(np.max(real_spot_y_1200_20s),np.sum(real_spot_y_1200_20s), np.mean(real_spot_y_1200_20s[35:45]))

plt.title('Spot Profile (20s)', fontsize=15)
plt.xlim(0,45)
plt.xticks([0,5,10,15,20,25,30,35,40,45], fontsize=15)
plt.yticks(fontsize=15)
plt.yscale('log')
#plt.ylim(.1,1e5)
plt.legend(fontsize=14)
plt.xlabel('$r - r_{centroid}$ [px]', fontsize=15)
plt.ylabel('$F$ [e-]', fontsize=15)
# Out:
# 125124.71456171114 1929589.352656222 3212.8466539183064
# 119099.9960884675 1896734.0738247226 3217.2838140277718
# 116358.091015625 1434655.5032706186 1012.4676393601101
# Text(0, 0.5, '$F$ [e-]')

# %%
plt.figure(figsize=(10,8), facecolor="white")
for px in range(50): plt.axvline(px, linestyle="--", lw=0.5, alpha=0.5, color="k")

def BinnedSpot(stamps):
    stamp = stamps[0]
    x = stamp.center.x
    y = stamp.center.y

    xs, ys = np.meshgrid(np.arange(stamp.array.shape[0]), np.arange(stamp.array.shape[1]))
    r = np.sqrt((xs - x)**2 + (ys - y)**2)
    radii = np.ravel([np.ravel(r) for n in range(len(stamps))])
    signals = np.ravel([np.ravel(i.array) for i in stamps])

    bins = np.linspace(0, 50, 200)

    y = []
    for j in range(len(bins)-1):

        cond = (radii>=bins[j]) & (radii<bins[j+1])
        selected_intensities = signals[cond]
        #print(selected_intensities.size)

        if selected_intensities.size==0:
            if j==0:
                y.append(np.nan)
            else:
                y.append(y[j-1])
        else:
            if selected_intensities.mean() == 0:
                y.append(y[j-1])
            else:
                y.append(selected_intensities.mean())

    return bins[0:-1], np.asarray(y)

x, y     = BinnedSpot(stamps)
x, y_wBF = BinnedSpot(stamps_wBF)

#from lmfit.models import GaussianModel
#model = GaussianModel()
#params = model.make_params(amplitude=np.sum(y), sigma=1, center=65.)
#params['center'].vary = False  # fix the centroid at 0
#result = model.fit(y, params, x=bins[0:-1]+65.)
#bkg = result.eval(x=bins[0:-1])

            
plt.plot(x, y, label='Simulated')
plt.plot(x, y_wBF, label='Simulated (incl. BF)')
plt.plot(x,real_spot_y_1200_20s, label='Real (radial avg. of spot #1200)')
print(np.max(y),np.sum(y),np.mean(y[35:45]))
print(np.max(y_wBF),np.sum(y_wBF),np.mean(y_wBF[35:45]))
print(np.max(real_spot_y_1200_20s),np.sum(real_spot_y_1200_20s), np.mean(real_spot_y_1200_20s[35:45]))

plt.title('Spot Profile (20s)', fontsize=15)
plt.xlim(0,10)
plt.xticks([0,5,10], fontsize=15)
plt.yticks(fontsize=15)
#plt.yscale('log')
#plt.ylim(.1,1e5)
plt.legend(fontsize=14)
plt.xlabel('$r - r_{centroid}$ [px]', fontsize=15)
plt.ylabel('$F$ [e-]', fontsize=15)
# Out:
# 122476.11270841195 1468838.4651017454 884.6451989533625
# 117593.57799217563 1436924.1831537236 898.0209189278333
# 116358.091015625 1434655.5032706186 1012.4676393601101
# Text(0, 0.5, '$F$ [e-]')

# %% [markdown]
# #### Simulated Lab Data

# %%
sigmas = []
fluxes = []
peakSignals = []
for exptime in [1.25, 2.5, 3.75, 5.0, 6.25, 7.5, 8.75, 10.0, 11.25, 12.5, 15.0, 17.5, 20.0, 22.5]:
    # add 4.5 microns sigma of Gaussian to model diffusion
    # convert 4.5 microns to arcsec with factor 0.2"/10micron 
    pixscale = 0.2/10.e-6
    dprof = galsim.Gaussian(sigma=2.30677178e-6*pixscale*1.002)

    # Airy function to simulate diffraction through mask
    lam_over_diam = 0.00000475  # radians
    lam_over_diam *= 206265  # Convert to arcsec
    airy = galsim.Airy(lam_over_diam)

    # convolve these terms
    prof = galsim.Convolve([dprof,airy]).shear(e1=-0.05, e2=0.06).withFlux(305180*.91893*1.08*.93*1.08*1.006*.95*(exptime/1.25))
    #prof = galsim.Add([prof,fprof])

    # add BF effect
    sensor = galsim.SiliconSensor(strength = 1.0, diffusion_factor=1.0, nrecalc=10000)

    # draw image
    blank_image = galsim.Image(65*3,65*3,scale=0.2,xmin=0,ymin=0,dtype=np.float64)  
    star_image1 = prof.drawImage(image=blank_image, offset=(-65.,0), scale=0.2, sensor=sensor, method="phot", save_photons=True)
    star_image2 = prof.drawImage(image=star_image1, offset=(-65.,65.), scale=0.2, sensor=sensor, method="phot", save_photons=True,add_to_image=True)
    star_image3 = prof.drawImage(image=star_image2, offset=(0,65.), scale=0.2, sensor=sensor, method="phot", save_photons=True,add_to_image=True)
    star_image4 = prof.drawImage(image=star_image3, offset=(65.,65.), scale=0.2, sensor=sensor, method="phot", save_photons=True,add_to_image=True)
    star_image5 = prof.drawImage(image=star_image4, offset=(65.,0), scale=0.2, sensor=sensor, method="phot", save_photons=True,add_to_image=True)
    star_image6 = prof.drawImage(image=star_image5, offset=(65.,-65), scale=0.2, sensor=sensor, method="phot", save_photons=True,add_to_image=True)
    star_image7 = prof.drawImage(image=star_image6, offset=(0,-65), scale=0.2, sensor=sensor, method="phot", save_photons=True,add_to_image=True)
    star_image8 = prof.drawImage(image=star_image7, offset=(-65.,-65.), scale=0.2, sensor=sensor, method="phot", save_photons=True,add_to_image=True)
    star_image = prof.drawImage(image=star_image8, scale=0.2, sensor=sensor, method="phot", save_photons=True,add_to_image=True)
    star_image += 118.0*exptime


    stamps = []
    sigmas_temp = []
    fluxes_temp = []
    peakSignals_temp = []
    for n in range(20):
        # random seed
        rng = galsim.BaseDeviate(n)
        temp = galsim.Image(star_image, dtype=star_image.dtype, copy=True)

        # generate noise and add to image
        noise = galsim.CCDNoise(rng, gain=1.5, read_noise=4.7, sky_level=0)
        temp.addNoise(noise)
        stamp = temp.subImage(galsim.BoundsI(temp.center.x - 33, temp.center.x + 33, temp.center.y - 33, temp.center.y + 33))
        #stamps.append(galsim.Image(stamp.array))
        
        mom = stamp.FindAdaptiveMom(weight=None, strict=False)
        sigmas_temp.append(mom.moments_sigma)
        fluxes_temp.append(mom.moments_amp)
        peakSignals_temp.append(np.max(stamp.array))

    sigmas.append(sigmas_temp)
    fluxes.append(fluxes_temp)
    peakSignals.append(peakSignals_temp)

# %%
sigmas_nosky = []
fluxes_nosky = []
peakSignals_nosky = []
for exptime in [1.25, 2.5, 3.75, 5.0, 6.25, 7.5, 8.75, 10.0, 11.25, 12.5, 15.0, 17.5, 20.0, 22.5]:
    # add 4.5 microns sigma of Gaussian to model diffusion
    # convert 4.5 microns to arcsec with factor 0.2"/10micron 
    pixscale = 0.2/10.e-6
    dprof = galsim.Gaussian(sigma=2.30677178e-6*pixscale*2)

    # Airy function to simulate diffraction through mask
    lam_over_diam = 0.00000475  # radians
    lam_over_diam *= 206265  # Convert to arcsec
    airy = galsim.Airy(lam_over_diam)

    # convolve these terms
    prof = galsim.Convolve([dprof,airy]).shear(e1=-0.05, e2=0.06).withFlux(305180*.91893*1.08*.93*1.08*1.006*.95*(exptime/1.25))
    #prof = galsim.Add([prof,fprof])

    # add BF effect
    sensor = galsim.SiliconSensor(strength = 1.0, diffusion_factor=1.0, nrecalc=10000)

    # draw image
    blank_image = galsim.Image(65*3,65*3,scale=0.2,xmin=0,ymin=0,dtype=np.float64)  
    star_image = prof.drawImage(image=blank_image, offset=(0,0), scale=0.2, sensor=sensor, method="phot", save_photons=True)
    star_image += 150.0*exptime


    stamps = []
    sigmas_temp = []
    fluxes_temp = []
    peakSignals_temp = []
    for n in range(20):
        # random seed
        rng = galsim.BaseDeviate(n)
        temp = galsim.Image(star_image, dtype=star_image.dtype, copy=True)

        # generate noise and add to image
        noise = galsim.CCDNoise(rng, gain=1.5, read_noise=4.7, sky_level=0)
        temp.addNoise(noise)
        stamp = temp.subImage(galsim.BoundsI(temp.center.x - 33, temp.center.x + 33, temp.center.y - 33, temp.center.y + 33))
        #stamps.append(galsim.Image(stamp.array))
        
        mom = stamp.FindAdaptiveMom(weight=None, strict=False)
        sigmas_temp.append(mom.moments_sigma)
        fluxes_temp.append(mom.moments_amp)
        peakSignals_temp.append(np.max(stamp.array))

    sigmas_nosky.append(sigmas_temp)
    fluxes_nosky.append(fluxes_temp)
    peakSignals_nosky.append(peakSignals_temp)

# %%
sigmas_true = []
fluxes_true = []
peakSignals_true = []
for exptime in [1.25, 2.5, 3.75, 5.0, 6.25, 7.5, 8.75, 10.0, 11.25, 12.5, 15.0, 17.5, 20.0, 22.5]:
    # add 4.5 microns sigma of Gaussian to model diffusion
    # convert 4.5 microns to arcsec with factor 0.2"/10micron 
    pixscale = 0.2/10.e-6
    dprof = galsim.Gaussian(sigma=2.37677178e-6*pixscale*1.002)

    # Airy function to simulate diffraction through mask
    lam_over_diam = 0.00000475  # radians
    lam_over_diam *= 206265  # Convert to arcsec
    airy = galsim.Airy(lam_over_diam)

    # convolve these terms
    prof = galsim.Convolve([dprof,airy]).shear(e1=-0.05, e2=0.06).withFlux(305180*.91893*1.08*1.006*(exptime/1.25))
    #prof = galsim.Add([prof,fprof])

    # add BF effect
    #sensor = galsim.SiliconSensor(strength = 1., diffusion_factor=1., nrecalc=10000)

    # draw image
    blank_image = galsim.Image(65*3,65*3,scale=0.2,xmin=0,ymin=0,dtype=np.float64)  
    star_image1 = prof.drawImage(image=blank_image, offset=(-65.,0), scale=0.2, method="phot", save_photons=True)
    star_image += 0.0


    stamps = []
    sigmas_temp = []
    fluxes_temp = []
    peakSignals_temp = []
    for n in range(20):
        # random seed
        rng = galsim.BaseDeviate(n)
        temp = galsim.Image(star_image, dtype=star_image.dtype, copy=True)

        # generate noise and add to image
        noise = galsim.CCDNoise(rng, gain=1.5, read_noise=4.7, sky_level=0)
        temp.addNoise(noise)
        stamp = temp.subImage(galsim.BoundsI(temp.center.x - 33, temp.center.x + 33, temp.center.y - 33, temp.center.y + 33))
        #stamps.append(galsim.Image(stamp.array))
        
        mom = stamp.FindAdaptiveMom(weight=None, strict=False)
        sigmas_temp.append(mom.moments_sigma)
        fluxes_temp.append(mom.moments_amp)
        peakSignals_temp.append(np.max(stamp.array))

    sigmas_true.append(sigmas_temp)
    fluxes_true.append(fluxes_temp)
    peakSignals_true.append(peakSignals_temp)

# %%
# plot it
f,ax = plt.subplots(1,1, figsize=(8,6))
from matplotlib.colors import LogNorm

#plt.scatter(np.asarray(fluxes)/1.5, .1 + np.asarray(sigmas),s=3)


plt.errorbar(np.mean(fluxes,axis=1)/1.5,np.mean(sigmas,axis=1),yerr=np.std(sigmas, axis=1), label='Simulated')
#m,b = np.polyfit(np.asarray(fluxes[20:-1])/1.5, np.asarray(sigmas[20:-1]), 1)
#plt.plot(np.linspace(0,3e6,10), m*np.linspace(0,3e6,10) + b, "--")
#plt.text(2.0e6,2.09,str(round(m*10000*100,3)) + "% / 10k ADU")


plt.errorbar(np.mean(fluxes_nosky,axis=1)/1.5, np.mean(sigmas_nosky, axis=1),np.std(sigmas_nosky, axis=1), label='Simulated (sky removed)')
#m,b = np.polyfit(np.asarray(fluxes_nosky[20:-1])/1.5, np.asarray(sigmas_nosky[20:-1]), 1)
#plt.plot(np.linspace(0,3e6,10), m*np.linspace(0,3e6,10) + b, "--")
#plt.text(2.0e6,2.09,str(round(m*10000*100,3)) + "% / 10k ADU")



plt.errorbar(np.mean(fluxes_real,axis=1)/1.5, np.mean(sigmas_real, axis=1),np.std(sigmas_real, axis=1), label='BOT Measurement')
#m,b = np.polyfit(np.asarray(fluxes_real)/1.5, np.asarray(sigmas_real), 1)
#plt.plot(np.linspace(0,3e6,10), m*np.linspace(0,3e6,10) + b, "--")
#plt.text(2.0e6,2.09,str(round(m*10000*100,3)) + "% / 10k ADU")

plt.legend()

plt.ylim(2.12,2.3)
plt.xlabel("Signal [ADU]")
plt.ylabel("HSM sigma")
plt.xlim(0,3.5e6)
# Out:
# (0.0, 3500000.0)

# %% [markdown]
# ### With increased BF + diffusion

# %%
# Out:
# 0.007283904699330016

# %%
# generate multiple of the same star (stochastic variation)
stars = []
for i in range(200):
    # random seed
    rng = galsim.BaseDeviate(i)

    # add 4.5 microns sigma of Gaussian to model diffusion
    # convert 4.5 microns to arcsec with factor 0.2"/10micron 
    pixscale = 0.2/10.e-6
    dprof = galsim.Gaussian(sigma=(9.0e-6)*pixscale)

    # Airy function to simulate diffraction through mask
    lam_over_diam = 0.00000491  # radians
    lam_over_diam *= 206265  # Convert to arcsec
    airy = galsim.Airy(lam_over_diam)


    # aadd shear term
    sprof = galsim.Shear(g1=0.05, g2=0.03)
    
    # add foreground light in photons/cm^2/s
    fprof = galsim.Box(66,66,flux=60000)

    # convolve these terms
    prof = galsim.Convolve([dprof,airy]).withFlux(10000+(i*10000))
    prof = galsim.Add([prof,fprof])

    # draw image
    blank_image = galsim.Image(66,66,scale=0.2,xmin=0,ymin=0,dtype=np.float64)  
    star_image = prof.drawImage(image=blank_image, scale=0.2, method="phot", save_photons=True)

    # add BF effect
    sensor = galsim.SiliconSensor(strength = 2.0, diffusion_factor=1., nrecalc=10000)
    photons = galsim.PhotonArray.makeFromImage(star_image)

    # generate noise and add to image
    noise = galsim.CCDNoise(rng, gain=1.5, read_noise=11.3, sky_level=0.0)
    star_image.addNoise(noise)
    
    stars.append(star_image)

# generate multiple stars with different noise levels
moments_sigma = [] # sigma
moments_amp = [] # flux
observed_shape = [] # shear
moments_centroid = [] # centroid
peak_signal = []
read_noise = []

for i,star in enumerate(stars):
    # calculate HSM moments (these are in pixel coordinates) for each star
    mom = star.FindAdaptiveMom(weight=None, strict=False)
    moments_sigma.append(mom.moments_sigma)
    moments_amp.append(mom.moments_amp)
    observed_shape.append(mom.observed_shape)
    moments_centroid.append(mom.moments_centroid)
    peak_signal.append(np.max(stars[i].array))
    read_noise.append(11.3)

    
# plot it
f,ax = plt.subplots(1,1)
print(np.mean(moments_sigma[-50:-1]))
im = ax.scatter(peak_signal,moments_sigma, s=4)
plt.ylabel("HSM sigma")
plt.xlabel("Peak signal [e-]")
plt.savefig("bf-simulation.png")
# Out:
# 2.268099625905355

# %%
plt.imshow(stars[0].array, norm=LogNorm())
plt.colorbar()

# %%
plt.imshow(stars[-1].array, norm=LogNorm())
plt.colorbar()

# %% [markdown]
# ## Same spot varying foreground light
